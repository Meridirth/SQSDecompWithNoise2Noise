# %%
import matplotlib
import numpy as np
import h5py

# %%
file1=h5py.File('/home/dwu/wfang/data/DualEnergyDualMaterial/Ye_noise_PhotonCountsE6_2_bin.mat','r')
Ye_noise_PhotonCountsE6_2_bin=file1['Ye_noise'][:,:,:]

# %%
file1
# Out:
# <HDF5 file "Ye_noise_PhotonCountsE6_2_bin.mat" (mode r)>

# %%
(Ye_noise_PhotonCountsE6_2_bin).shape
# Out:
# (2, 256, 900)

# %%
sino = Ye_noise_PhotonCountsE6_2_bin.reshape(2,256,900,1)
sino.shape
np.save('/home/dwu/wfang/data/DualEnergyDualMaterial/sino.npy',sino)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[6,6])
plt.imshow(sino[0,:,:,0],'gray')

# %%
file2=h5py.File('/home/dwu/wfang/data/DualEnergyDualMaterial/X_ref_PhotonCountsE6_2_bin.mat','r')

# %%
X_ref_PhotonCountsE6_2_bin = file2['X_ref'][:,:,:]

# %%
X_ref_PhotonCountsE6_2_bin.shape
# Out:
# (2, 256, 256)

# %%
ref = X_ref_PhotonCountsE6_2_bin.reshape(2,256,256,1)
ref = ref.transpose((0,2,1,3))
np.save('/home/dwu/wfang/data/DualEnergyDualMaterial/ref.npy',ref)

# %%
ref2=np.load('ref.npy')
import matplotlib.pyplot as plt
plt.figure(figsize=[6,6])
plt.imshow(ref2[0,:,:,0],'gray')

# %%
file3=h5py.File('/home/dwu/wfang/data/DualEnergyDualMaterial/miu_basis_matrix.mat','r')

# %%
miu_basis_matrix = file3['miu_basis_matrix'][:,:].T

# %%
print(miu_basis_matrix)
# Out:
# [[0.61295138 0.22201954]
#  [0.33931923 0.1813193 ]]

# %%
miu_basis_matrix[0,1]
# Out:
# 0.22201954075831987

# %%
np.save('/home/dwu/wfang/data/DualEnergyDualMaterial/miu_basis_matrix.npy',miu_basis_matrix)
