# %%
import matplotlib
import numpy as np
import h5py
import scipy.io

# %%
file1=scipy.io.loadmat('/home/dwu/wfang/data/FourEnergyTwoMaterial/PhotonCountsE8/Ye_noise_PhotonCountsE8_4_bin.mat')
Ye_noise_PhotonCountsE5_4_bin=file1['Ye_noise'][:,:,:]

# %%
(Ye_noise_PhotonCountsE5_4_bin.T).shape
# Out:
# (4, 256, 900)

# %%
sino = Ye_noise_PhotonCountsE5_4_bin.T.reshape(4,256,900,1)
sino.shape
# Out:
# (4, 256, 900, 1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[6,6])
plt.imshow(sino[0,:,:,0],'gray')

# %%
np.save('sino.npy',sino)

# %%
file2=scipy.io.loadmat('/home/dwu/wfang/data/FourEnergyTwoMaterial/PhotonCountsE8/X_ref_PhotonCountsE8_4_bin.mat')

# %%
X_ref_PhotonCountsE5_4_bin = file2['X_ref'][:,:,:]

# %%
X_ref_PhotonCountsE5_4_bin.T.shape
# Out:
# (4, 256, 256)

# %%
ref = X_ref_PhotonCountsE5_4_bin.T.reshape(4,256,256,1)

# %%
ref = ref.transpose((0,2,1,3))

# %%
np.save('ref.npy',ref)

# %%
ref.shape
# Out:
# (4, 256, 256, 1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[6,6])
plt.imshow(ref[3,:,:,0],'gray')

# %%
file3=scipy.io.loadmat('/home/dwu/wfang/data/FourEnergyTwoMaterial/PhotonCountsE8/miu_basis_matrix.mat')

# %%
miu_basis_matrix = file3['miu_basis_matrix'][:,:]

# %%
print(miu_basis_matrix)
# Out:
# [[0.74460653 0.23854891 0.37082794]
#  [0.47933095 0.20541878 0.27346084]
#  [0.39021154 0.19117289 0.23609825]
#  [0.29927271 0.17328147 0.19519981]]

# %%
miu_basis_matrix[0,1]
# Out:
# 0.23854891337439213

# %%
np.save('miu_basis_matrix.npy',miu_basis_matrix)
